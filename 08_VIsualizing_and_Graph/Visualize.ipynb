# %%
# 02. Line Graph
# %matplotlib inline

import pandas as pd

# %%
df = pd.read_csv('broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot() # default : df.plot(kind='line')

# %%
# only one column
df.plot(y='KBS')

# %%
# multi column needs to be list
df.plot(y=['KBS', 'JTBC'])

# %%
# different way
df[['KBS', 'JTBC']].plot()

# %%
# what about strings? > see next
# 03, 04 Quiz

# %%
# 05. Bar Graph
df_sport = pd.read_csv('sports.csv', index_col=0)
df_sport
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
# not understandable
df_sport.plot()

# %%
df_sport.plot(kind='bar')

# %%
# if want this into horizontal line
df_sport.plot(kind='barh') # for "BAR Horizantonal"

# %%
# stack available
df_sport.plot(kind='bar', stacked=True)

# %%
df_sport['Female'].plot(kind='bar')

# %%
# 07. Pie Graph
df.loc[2017]
# Out:
# KBS          26.890
# MBC          12.465
# SBS           8.661
# TV CHOSUN     8.886
# JTBC          9.453
# Channel A     6.056
# MBN           5.215
# Name: 2017, dtype: float64

# %%
df.loc[2017].plot(kind='pie')

# %%
# 11. Histogram
df = pd.read_csv('body.csv', index_col=0)
df.head(10)
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# 6        175.4    72.7
# 7        181.5    87.9
# 8        174.2    64.5
# 9        176.4    57.5
# 10       175.8    66.4

# %%
df.plot(kind='hist', y='Height')
# what is default bin?

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.plot(kind='hist', y='Height', bins=15)

# %%
df.plot(kind='hist', y='Height', bins=200)
# what gives you better insight?

# %%
# 14. Box Plot

# %% [markdown]
# ![image.png](attachment:image.png)
# box and whisker plot

# %%
df_exam = pd.read_csv("exam.csv")
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exam['math score'].describe()
# describe() vs info()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exam.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df_exam.plot(kind='box', y='math score')

# %%
df_exam.plot(kind='box', y=['math score', 'reading score', 'writing score'])

# %%
df_semi = pd.read_csv('semiconductor.csv', index_col=0)
df_semi.head(5)
df_semi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 2015440028 to 2017440150
# Data columns (total 3 columns):
# 380    64 non-null int64
# 455    64 non-null int64
# 835    64 non-null int64
# dtypes: int64(3)
# memory usage: 2.0 KB

# %%
df_semi.plot(kind='box', y=['380', '455', '835'])

# %%
# 17. Scatter Plot
df_exam.plot(kind='scatter', x='math score', y='reading score')

# %%
df_exam.plot(kind='scatter', x='writing score', y='reading score')

# %%
df_exam.plot(kind='scatter', x='writing score', y='math score')
