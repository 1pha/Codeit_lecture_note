# %%
# Chapter 9. Seaborn
# much more graphs than pandas
import seaborn as sns
import pandas as pd

# %%
# 02. Probability Density Function
# Statistical Data Visualization
# PDF represents distribution
# probability equals to Area under the graph
# the total Area = 1

# %%
# 03. Quiz
# 04. KDE plot
# KDE : Kernel Density Estimation
# 어느 정도 추측해서 진짜 그림으로 근사화(fitting이랑 비슷한듯)
body_df = pd.read_csv('body.csv', index_col=0)
body_df.head(5)
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
body_df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
# 6       175.4
# 7       181.5
# 8       174.2
# 9       176.4
# 10      175.8
# 11      162.9
# 12      176.2
# 13      173.5
# 14      163.9
# 15      165.6
# 16      176.4
# 17      174.4
# 18      178.4
# 19      175.7
# 20      178.2
# 21      169.5
# 22      160.0
# 23      167.6
# 24      171.2
# 25      154.4
# 26      177.7
# 27      163.0
# 28      180.4
# 29      169.7
# 30      184.8
#         ...
# 971     173.5
# 972     171.7
# 973     175.8
# 974     170.6
# 975     163.8
# 976     180.4
# 977     173.6
# 978     178.3
# 979     176.1
# 980     172.8
# 981     169.4
# 982     169.2
# 983     180.9
# 984     180.8
# 985     165.2
# 986     163.2
# 987     172.2
# 988     178.9
# 989     176.7
# 990     177.4
# 991     165.9
# 992     175.2
# 993     170.5
# 994     171.9
# 995     166.4
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
type(body_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(body_df['Height'])
# Out:
# pandas.core.series.Series

# %%
body_df['Height'].value_counts().sort_index().plot()
# doesn't look good

# %%
sns.kdeplot(body_df['Height'])
# seems better than we thought
# Out:
# C:\Users\J\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(body_df['Height'], bw=.05)
# less smooth

# %%
sns.kdeplot(body_df['Height'], bw=.5)
# more smooth
# bw = bid width ... maybe...?
# guess bw defaults to around 1 ~ 1.2

# %%
# 07. KDE 활용 예시
# change graph more smoothly than real data
body_df.plot(kind='hist', y='Height')

# %%
body_df.plot(kind='hist', y='Height', bins=15)

# %%
# seaborn으로 histogram 위에 얹을 수 있음
sns.distplot(body_df['Height'], bins=15)

# %%
body_df.plot(kind='box', y='Height')

# %%
sns.violinplot(y=body_df['Height'])
# 90도 돌린 모양

# %%
body_df.plot(kind='scatter', x='Height', y='Weight')

# %%
sns.kdeplot(body_df['Height'], body_df['Weight'])
# body_df.plot(kind='hist', y='Height')
# body_df.plot(kind='hist', y='Weight')
# draw above 2 and see the graph below in horizontal way and vertical way

# %%
# 10. LM Plot
sns.lmplot(data=body_df, x='Height', y='Weight')
# draw regression line

# %%
# 11. Visualization by Category
laptops_df = pd.read_csv('laptops.csv')
laptops_df.head(5)
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# 2                2.0    mac    1.35      NaN
# 3                2.0    mac    3.02      NaN
# 4                2.0    mac    3.02      NaN

# %%
laptops_df['os'].unique()
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
sns.catplot(data=laptops_df, x='os', y='price', kind='box')
# kind : how are we going to compare those two

# %%
sns.catplot(data=laptops_df, x='os', y='price', kind='violin')
# Out:
# C:\Users\J\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(data=laptops_df, x='os', y='price', kind='strip')
# if we want to see how much datas are inthere

# %%
laptops_df['processor_brand'].unique()
# Out:
# array(['intel', 'amd'], dtype=object)

# %%
sns.catplot(data=laptops_df, x='os', y='price', kind='strip', hue='processor_brand')

# %%
sns.catplot(data=laptops_df, x='os', y='price', kind='swarm', hue='processor_brand')
