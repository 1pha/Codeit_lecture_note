# %%
# 03. Popular Career?
import pandas as pd
import seaborn as sns

df = pd.read_csv('occupations.csv', index_col=0)
df.head(5)
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
df_female = df[df['gender'] == 'F']
df_female['occupation'].value_counts()
# Out:
# student          60
# other            36
# administrator    36
# librarian        29
# educator         26
# writer           19
# artist           13
# healthcare       11
# marketing        10
# homemaker         6
# programmer        6
# none              4
# salesman          3
# executive         3
# scientist         3
# engineer          2
# lawyer            2
# entertainment     2
# technician        1
# retired           1
# Name: occupation, dtype: int64

# %%
type(df_female[['occupation', 'zip_code']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_female['occupation'])
# Out:
# pandas.core.series.Series

# %%
df_male = df[df['gender'] == 'M']
df_male['occupation'].value_counts()
# Out:
# student          136
# educator          69
# other             69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# technician        26
# writer            26
# librarian         22
# marketing         16
# entertainment     16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# none               5
# healthcare         5
# homemaker          1
# Name: occupation, dtype: int64

# %%
# 05 Quiz. Brucn cafe Music Selection
import pandas as pd
import seaborn as sns

df = pd.read_csv('young_survey.csv')
hard_on_morning = df[df['Getting up'] == 1]
df.corr()['Getting up'].sort_values(ascending=True)
# Out:
# Prioritising workload        -0.256098
# Finances                     -0.202493
# Workaholism                  -0.163420
# Healthy eating               -0.145313
# Reliability                  -0.139184
# Physics                      -0.138385
# Age                          -0.119888
# Happiness in life            -0.116574
# Chemistry                    -0.114936
# Active sport                 -0.110472
# Mathematics                  -0.109566
# Documentary                  -0.102092
# Thinking ahead               -0.096450
# Energy levels                -0.090133
# Spending on healthy eating   -0.084574
# Science and technology       -0.084106
# Keeping promises             -0.076505
# Gardening                    -0.075320
# Opera                        -0.071819
# Western                      -0.071302
# Biology                      -0.070370
# Action                       -0.067689
# Religion                     -0.066783
# Parents' advice              -0.062700
# ...

# %%
import pandas as pd

df = pd.read_csv('young_survey.csv')
df.corr()
brunch_df = df.corr()['Getting up']
brunch_df[1:19].sort_values(ascending=True)
# Out:
# Opera                      -0.071819
# Slow songs or fast songs   -0.052613
# Folk                       -0.049612
# Punk                       -0.029189
# Metal or Hardrock          -0.026769
# Country                    -0.025315
# Latino                     -0.015060
# Reggae, Ska                -0.008434
# Musical                     0.011869
# Classical music             0.014285
# Swing, Jazz                 0.019556
# Techno, Trance              0.019863
# Dance                       0.027249
# Alternative                 0.027540
# Rock n roll                 0.028889
# Hiphop, Rap                 0.038980
# Pop                         0.079101
# Rock                        0.105245
# Name: Getting up, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
#        'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock',
#        ...
#        'Spending on looks', 'Spending on gadgets',
#        'Spending on healthy eating', 'Age', 'Height', 'Weight',
#        'Number of siblings', 'Gender', 'Handedness', 'Education'],
#       dtype='object', length=147)

# %%
# 06 Quiz. Startup Item
start_up = df[['Branded clothing', 'Healthy eating', 'Musical instruments', 'New environment',
              'Prioritising workload', 'Spending on looks', 'Workaholism', 'Writing', 'Writing notes']]
start_up.corr()
# Out:
#                        Branded clothing  Healthy eating  Musical instruments  \
# Branded clothing               1.000000        0.086229            -0.081135
# Healthy eating                 0.086229        1.000000             0.073319
# Musical instruments           -0.081135        0.073319             1.000000
# New environment                0.060765        0.059311             0.054590
# Prioritising workload          0.010480        0.242131             0.075620
# Spending on looks              0.418399        0.130878            -0.040460
# Workaholism                   -0.013694        0.238644             0.091071
# Writing                       -0.099731        0.008610             0.343816
# Writing notes                 -0.025140        0.166951             0.106172
#
#                        New environment  Prioritising workload  \
# Branded clothing              0.060765               0.010480
# Healthy eating                0.059311               0.242131
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country', 'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock', 'Punk', 'Hiphop, Rap', 'Reggae, Ska', 'Swing, Jazz', 'Rock n roll', 'Alternative', 'Latino', 'Techno, Trance', 'Opera', 'Movies', 'Horror', 'Thriller', 'Comedy', 'Romantic', 'Sci-fi', 'War', 'Fantasy/Fairy tales', 'Animated', 'Documentary', 'Western', 'Action', 'History', 'Psychology', 'Politics', 'Mathematics', 'Physics', 'Internet', 'PC', 'Economy Management', 'Biology', 'Chemistry', 'Reading', 'Geography', 'Foreign languages', 'Medicine', 'Law', 'Cars', 'Art exhibitions', 'Religion', 'Countryside, outdoors', 'Dancing', 'Musical instruments', 'Writing', 'Passive sport', 'Active sport', 'Gardening', 'Celebrities', 'Shopping', 'Science and technology', 'Theatre', 'Fun with friends', 'Adrenaline sports', 'Pets', 'Flying', 'Storm', 'Darkness', 'Heights', 'Spiders', 'Snakes', 'Rats', 'Ageing', 'Dangerous dogs', 'Fear of public speaking', 'Smoking', 'Alcohol
# ...

# %%
# 08, 09 Quiz. Movie Cafe
movie_df = pd.read_csv('survey.csv')
movie_df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock        ...          \
# 0      1.0  5.0   5.0                1.0        ...
# 1      2.0  3.0   5.0                4.0        ...
# 2      5.0  3.0   5.0                3.0        ...
# 3      1.0  2.0   2.0                1.0        ...
# 4      3.0  5.0   3.0                1.0        ...
#
#    Spending on looks  Spending on gadgets  Spending on healthy eating   Age  \
# 0                3.0                    1                         3.0  20.0
# ...

# %%
movie = movie_df.loc[:, 'Horror':'Action']
sns.clustermap(movie.corr())

# %%
# 11. Titanic EDA
titanic = pd.read_csv('titanic.csv', index_col=0)
sns.violinplot(titanic['Age'])
# Out:
# C:\Users\J\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fare_age = titanic[['Fare', 'Age']]
sns.jointplot(data=fare_age, x='Age', y='Fare')

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
p_s = titanic[['Pclass', 'Survived']]
third = titanic[titanic['Pclass'] == 3]
second = titanic[titanic['Pclass'] == 2]
first = titanic[titanic['Pclass'] == 1]
first['Survived'].value_counts()
# Out:
# 1    136
# 0     80
# Name: Survived, dtype: int64

# %%
second['Survived'].value_counts()
# Out:
# 0    97
# 1    87
# Name: Survived, dtype: int64

# %%
third['Survived'].value_counts()
# Out:
# 0    372
# 1    119
# Name: Survived, dtype: int64

# %%
sns.catplot(data=titanic, x='Age', y='Survived', kind='box')

# %%
sns.kdeplot(titanic['Age'])

# %%
young = titanic[titanic['Age'] < 25]
old = titanic[titanic['Age'] >= 25]
young['Survived'].value_counts()
# Out:
# 0    160
# 1    118
# Name: Survived, dtype: int64

# %%
old['Survived'].value_counts()
# Out:
# 0    264
# 1    172
# Name: Survived, dtype: int64

# %%
118 / (160+118)
# Out:
# 0.4244604316546763

# %%
172 / (172+264)
# Out:
# 0.3944954128440367

# %%
sns.clustermap(titanic.corr(), annot=True)

# %%
# Solution
# 1. Age : 30, 40s are the most
titanic.plot(kind='hist', y='Age', bins=30)
# 정확히 어디가 많은지 보려면 seaborn보다 pandas histogram이 좋은 것 같다

# %%
# 2. The Largest Fare was paid by 30s
titanic.plot(kind='scatter', x='Age', y='Fare')

# %%
# 3. There are More survivors than deaths.
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# 4. There were most people in 3rd class
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 5. People in the 1st class mostly survived
titanic.plot(kind='scatter', x='Pclass', y='Survived')
# doesn't give us much information

# %%
sns.kdeplot(titanic['Pclass'], titanic['Survived'])

# %%
# 6. Younger people survived more than the olds
sns.stripplot(data=titanic, x='Survived', y="Age")

# %%
sns.violinplot(data=titanic, x='Survived', y='Age')
# doesn't seem age actually offers good information about peoples' survival

# %%
# 7. Gender effects on survival more than age
sns.stripplot(data=titanic, x='Survived', y="Age", hue="Sex")

# %%
sns.catplot(data=titanic, x='Sex', y="Age", kind="swarm", hue="Survived")
