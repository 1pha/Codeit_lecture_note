# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

# %%
laptops_df = pd.read_csv('laptops.csv')

# %%
# to see only first or last datum, default value=5
laptops_df.head(3)
laptops_df.tail(3)
# Out:
#    brand             model  ram hd_type  hd_size  screen_size  price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6  40000
# 1  Apple       MacBook Air    8     ssd      128         13.3  55499
# 2  Apple       MacBook Air    8     ssd      256         13.3  71500
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# 2                2.0    mac    1.35      NaN
#     brand           model  ram hd_type  hd_size  screen_size  price  \
# 164  Asus          X554LD    2     hdd      500         15.6  29199
# 165  Asus  X550LAV-XX771D    2     hdd      500         15.6  29990
# ...

# %%
laptops_df.shape
type(laptops_df.shape)

laptops_df.columns
type(laptops_df.columns)
# Out:
# (167, 15)
# tuple
# Index(['brand', 'model', 'ram', 'hd_type', 'hd_size', 'screen_size', 'price',
#        'processor_brand', 'processor_model', 'clock_speed',
#        'graphic_card_brand', 'graphic_card_size', 'os', 'weight', 'comments'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
# info : tells us how many datums, what kind of datums are in there
# only for DataFrame
laptops_df.info()
#laptops_df['brand'].info()

# describe : tells us statistical values(different by DataFrame/Series)
laptops_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
# brand                 167 non-null object
# model                 167 non-null object
# ram                   167 non-null int64
# hd_type               167 non-null object
# hd_size               167 non-null int64
# screen_size           167 non-null float64
# price                 167 non-null int64
# processor_brand       167 non-null object
# processor_model       167 non-null object
# clock_speed           166 non-null float64
# graphic_card_brand    163 non-null object
# graphic_card_size     81 non-null float64
# os                    167 non-null object
# weight                160 non-null float64
# comments              55 non-null object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 19.6+ KB
#               ram     hd_size  screen_size          price  clock_speed  \
# count  167.000000   167.00000   167.000000     167.000000   166.000000
# ...

# %%
# sort_values
laptops_df.sort_values(by='price') # 오름차순
laptops_df.sort_values(by='price', ascending=False) # 내림차순
laptops_df.sort_values(by='price', ascending=False, inplace=True)
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 143       Acer                Aspire ES 15    4     hdd     1024         15.6
# 158       Asus               X540YA-XO290D    4     hdd     1024         15.6
# 14        Dell            Inspiron 15 3565    4     hdd      500         15.0
# 9         Dell          Inspiron 15.6 3552    4     hdd      500         15.0
# 119         HP              245 G4,P1b38PA    4     ssd     1024         15.6
# 159       Asus                     P2420SA    4     hdd      500         14.0
# ...

# %%
# Feature informations (for Series)
laptops_df['brand'].unique() # unique features
laptops_df['brand'].value_counts() # how many datums in each feature
laptops_df['brand'].describe() # tells us the best countable feature
# Out:
# array(['Dell', 'Apple', 'Acer', 'HP', 'Lenovo', 'Alienware', 'Microsoft',
#        'Asus'], dtype=object)
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Alienware     6
# Microsoft     6
# Name: brand, dtype: int64
# count     167
# unique      8
# top        HP
# freq       55
# Name: brand, dtype: object

# %%
# Quiz
df = pd.read_csv('world_cities.csv', index_col=0)
df.head(10)
# Out:
#   City / Urban area     Country  Population  Land area (in sqKm)
# 0      Buenos Aires   Argentina    11200000                 2266
# 1         Melbourne   Australia     3162000                 2080
# 2            Sydney   Australia     3502000                 1687
# 3          Brisbane   Australia     1508000                 1603
# 4             Perth   Australia     1177000                  964
# 5          Adelaide   Australia     1002000                  729
# 6        Gold Coast   Australia      422000                  383
# 7            Vienna     Austria     1550000                  453
# 8     Baku/Sumqayit  Azerbaijan     2100000                  544
# 9          Brussels     Belgium     1570000                  712

# %%
# 1. How many Citys and Countries?
df['City / Urban area'].describe()
df['Country'].describe()
# or
df['City / Urban area'].value_counts().shape
df['Country'].value_counts().shape
# Out:
# count          249
# unique         249
# top       Taichung
# freq             1
# Name: City / Urban area, dtype: object
# count     249
# unique     61
# top       USA
# freq      105
# Name: Country, dtype: object
# (249,)
# (61,)

# %%
# 2. High Population Density
df['Population Density'] = df['Population'] / df['Land area (in sqKm)']
df.loc[df['Population Density'] > 10000, 'Population Density'].describe()
df[df['Population Density'] > 10000].info()
# Out:
# count       19.000000
# mean     14636.526358
# std       5223.133249
# min      10112.359551
# 25%      10614.746965
# 50%      13404.825737
# 75%      16924.968394
# max      29648.760331
# Name: Population Density, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 32 to 129
# Data columns (total 5 columns):
# City / Urban area      19 non-null object
# Country                19 non-null object
# Population             19 non-null int64
# Land area (in sqKm)    19 non-null int64
# Population Density     19 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 912.0+ bytes

# %%
# 3. Highest Population Density
df[df['Population Density'] > 10000].sort_values(by='Population Density', ascending=False)
# Out:
#     City / Urban area      Country  Population  Land area (in sqKm)  \
# 75             Mumbai        India    14350000                  484
# 74            Kolkata        India    12700000                  531
# 101           Karachi     Pakistan     9800000                  518
# 99              Lagos      Nigeria    13400000                  738
# 34           Shenzhen        China     8000000                  466
# 123     Seoul/Incheon  South Korea    17500000                 1049
# 129            Taipei       Taiwan     5700000                  376
# 76            Chennai        India     5950000                  414
# 38             Bogota     Colombia     7000000                  518
# 33           Shanghai        China    10000000                  746
# 102              Lima         Peru     7000000                  596
# 32            Beijing        China     8614000                  748
# 71              Delhi        India    14300000                 1295
# ...

# %%
# 4. 4 cities in the datum, which conutry?
df['Country'].value_counts(ascending=False)
type(df['Country'].value_counts(ascending=False)) # Series
countries = df['Country'].value_counts(ascending=False)
countries[countries == 4]
# Out:
# USA             105
# France           15
# Brazil           10
# Canada            9
# Germany           8
# India             6
# China             6
# South Africa      6
# Australia         6
# Japan             5
# UK                5
# Italy             4
# Mexico            3
# Russia            3
# Belgium           2
# Saudi Arabia      2
# Taiwan            2
# Turkey            2
# Pakistan          2
# Portugal          2
# Poland            2
# UAE               2
# Congo             2
# Puerto Rico       2
# Spain             2
# South Korea       1
# Egypt             1
# Chile             1
# Netherlands       1
# Ghana             1
#                ...
# Iraq              1
# Indonesia         1
# Singapore         1
# Sweden            1
# Thailand          1
# Saudi             1
# Colombia          1
# Lebanon           1
# Ireland           1
# Israel            1
# Uzbekistan        1
# Iran              1
# Ecuador           1
# Greece            1
# ...

# %%
import pandas as pd
# Quiz 2
enroll_df = pd.read_csv('enrollment_1.csv')

# %%
enroll_df['status'] = 'allowed'
freshman_info = (enroll_df['year'] == 1) & (enroll_df['course name'] == 'information technology')
commerce = (enroll_df['year'] == 4) & (enroll_df['course name'] == 'commerce')
enroll_df.loc[freshman_info | commerce, 'status'] = 'not allowed'
enroll_df[enroll_df['status'] == 'allowed'].head(10)
enroll_df['status'].value_counts()
# Out:
#         id  year    course name   status
# 0  2777729     1        science  allowed
# 1  2777730     2        science  allowed
# 2  2777765     1           arts  allowed
# 3  2777766     2           arts  allowed
# 4  2777785     1            mba  allowed
# 5  2777786     2            mba  allowed
# 6  2777793     1  mba 2nd shift  allowed
# 7  2777794     2  mba 2nd shift  allowed
# 8  2777795     1  mca 2nd shift  allowed
# 9  2777796     2  mca 2nd shift  allowed
# allowed        1990
# not allowed      10
# Name: status, dtype: int64

# %%
less_5 = enroll_df['course name'].value_counts() < 5
indices = less_5[less_5 == True]
for i, data in enumerate(list(enroll_df['course name'])):
    if enroll_df.iloc[i, 2] in indices:
        enroll_df.iloc[i, 3] = 'not allowed'

# %%
enroll_df['status'].value_counts()
# Out:
# allowed        1448
# not allowed     552
# Name: status, dtype: int64

# %%
enroll_df.iloc[3,2]
# Out:
# 'arts'

# %%
enroll_df['status'].value_counts()
# Out:
# allowed        1448
# not allowed     552
# Name: status, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('data/enrolment_1.csv')
df['status'] = 'allowed'

freshman_info = (df['year'] == 1) & (df['course name'] == 'information technology')
commerce_seni = (df['year'] == 4) & (df['course name'] == 'commerce')
df.loc[freshman_info | commerce_seni, 'status'] = 'not allowed'

less_5 = df['course name'].value_counts() < 5
indices = less_5[less_5 == True]
for i, data in enumerate(list(df['course name'])):
    if df.iloc[i, 2] in indices:
        df.iloc[i, 3] = 'not allowed'
        
df

df = pd.read_csv('data/enrolment_1.csv')
df["status"] = "allowed"

# 조건 1
boolean1 = df["course name"] == "information technology"
boolean2 = df["year"] == 1
df.loc[boolean1 & boolean2, "status"] = "not allowed"

# 조건 2
boolean3= df["course name"] == "commerce"
boolean4= df["year"] == 4
df.loc[boolean3& boolean4, "status"] = "not allowed"

# 조건 3
allowed = df["status"] == "allowed"
course_counts = df.loc[allowed, "course name"].value_counts()
closed_courses = list(course_counts[course_counts < 5].index)
for course in closed_courses:
    df.loc[df["course name"] == course, "status"] = "not allowed"

# 정답 확인
df

# %%
import pandas as pd

df = pd.read_csv('enrollment_2.csv')
df.head(10)
# Out:
#         id  year    course name       status
# 0  2777729     1        science      allowed
# 1  2777730     2        science      allowed
# 2  2777765     1           arts      allowed
# 3  2777766     2           arts      allowed
# 4  2777785     1            mba      allowed
# 5  2777786     2            mba      allowed
# 6  2777793     1  mba 2nd shift  not allowed
# 7  2777794     2  mba 2nd shift  not allowed
# 8  2777795     1  mca 2nd shift  not allowed
# 9  2777796     2  mca 2nd shift  not allowed

# %%
df['room assignment'] = 'default'
student = df['course name'].value_counts()
# indices
eighty = student >= 80
auditorium = eighty[eighty==True].index

forty_eighty = (student < 80) & (student >= 40)
large_room = forty_eighty[forty_eighty==True].index

fifteen_forty = (student < 40) & (student >= 15)
medium_room = fifteen_forty[fifteen_forty==True].index

five_fifteen = (student < 15) & (student >= 5)
small_room = five_fifteen[five_fifteen==True].index

for i, data in enumerate(list(df['course name'])):
    if df.iloc[i, 3] == 'allowed':
        if data in list(auditorium):
            df.iloc[i, 4] = 'Auditorium'
        elif data in list(large_room):
            df.iloc[i, 4] = 'Large room'
        elif data in list(medium_room):
            df.iloc[i, 4] = 'Medium room'
        elif data in list(small_room):
            df.iloc[i, 4] = 'Small room'
    elif df.iloc[i, 3] == 'not allowed':
        df.iloc[i, 4] = 'not assigned'

# %%
import pandas as pd

df = pd.read_csv('enrollment_3.csv')
df['room assignment'].unique()
# Out:
# array(['Auditorium', 'Small room', 'not assigned', 'Medium room',
#        'Large room'], dtype=object)

# %%
auditorium = {key: value + 1 for value, key 
              in enumerate(sorted(list(df.loc[df['room assignment'] == 'Auditorium', 'course name'].unique())))}
large_room = {key: value + 1 for value, key
             in enumerate(sorted(list(df.loc[df['room assignment'] == 'Large room', 'course name'].unique())))}
medium_room = {key: value + 1 for value, key
              in enumerate(sorted(list(df.loc[df['room assignment'] == 'Medium room', 'course name'].unique())))}
small_room = {key: value + 1 for value, key
             in enumerate(sorted(list(df.loc[df['room assignment'] == 'Small room', 'course name'].unique())))}

# %%
for i, data in enumerate(list(df['room assignment'])):
    if df.iloc[i, 4] != 'not assigned':
        if df.iloc[i, 4] == 'Auditorium':
            df.iloc[i, 4] = 'Auditorium-' + str(auditorium[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Large room':
            df.iloc[i, 4] = 'Large room-' + str(large_room[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Medium room':
            df.iloc[i, 4] = 'Medium room-' + str(medium_room[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Small room':
            df.iloc[i, 4] = 'Small room-' + str(small_room[df.iloc[i, 2]])
df.rename(columns={'room assignment': 'room number'}, inplace=True)

# %%
df.head(10)
# Out:
#         id  year    course name       status    room number
# 0  2777729     1        science      allowed   Auditorium-3
# 1  2777730     2        science      allowed   Auditorium-3
# 2  2777765     1           arts      allowed   Auditorium-1
# 3  2777766     2           arts      allowed   Auditorium-1
# 4  2777785     1            mba      allowed  Small room-34
# 5  2777786     2            mba      allowed  Small room-34
# 6  2777793     1  mba 2nd shift  not allowed   not assigned
# 7  2777794     2  mba 2nd shift  not allowed   not assigned
# 8  2777795     1  mca 2nd shift  not allowed   not assigned
# 9  2777796     2  mca 2nd shift  not allowed   not assigned

# %%
import pandas as pd

df = pd.read_csv('enrollment_3.csv')

# 코드를 작성하세요.
auditorium = {key: value + 1 for value, key 
              in enumerate(sorted(list(df.loc[df['room assignment'] == 'Auditorium', 'course name'].unique())))}
large_room = {key: value + 1 for value, key
             in enumerate(sorted(list(df.loc[df['room assignment'] == 'Large room', 'course name'].unique())))}
medium_room = {key: value + 1 for value, key
              in enumerate(sorted(list(df.loc[df['room assignment'] == 'Medium room', 'course name'].unique())))}
small_room = {key: value + 1 for value, key
             in enumerate(sorted(list(df.loc[df['room assignment'] == 'Small room', 'course name'].unique())))}

for i, data in enumerate(list(df['room assignment'])):
    if df.iloc[i, 4] != 'not assigned':
        if df.iloc[i, 4] == 'Auditorium':
            df.iloc[i, 4] = 'Auditorium-' + str(auditorium[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Large room':
            df.iloc[i, 4] = 'Large-' + str(large_room[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Medium room':
            df.iloc[i, 4] = 'Medium-' + str(medium_room[df.iloc[i, 2]])
        if df.iloc[i, 4] == 'Small room':
            df.iloc[i, 4] = 'Small-' + str(small_room[df.iloc[i, 2]])
df.rename(columns={'room assignment': 'room number'}, inplace=True)
# 정답 출력
df
# Out:
#            id  year           course name       status   room number
# 0     2777729     1               science      allowed  Auditorium-3
# 1     2777730     2               science      allowed  Auditorium-3
# 2     2777765     1                  arts      allowed  Auditorium-1
# 3     2777766     2                  arts      allowed  Auditorium-1
# 4     2777785     1                   mba      allowed      Small-34
# 5     2777786     2                   mba      allowed      Small-34
# 6     2777793     1         mba 2nd shift  not allowed  not assigned
# 7     2777794     2         mba 2nd shift  not allowed  not assigned
# 8     2777795     1         mca 2nd shift  not allowed  not assigned
# 9     2777796     2         mca 2nd shift  not allowed  not assigned
# 10    2777797     3         mca 2nd shift  not allowed  not assigned
# 11    2777798     1                  bjmc  not allowed  not assigned
# 12    2777799     2                  bjmc  not allowed  not assigned
# ...

# %%
import pandas as pd

df = pd.read_csv('data/enrolment_3.csv')

# 과목별 인원 가져오기
allowed = df["status"] == "allowed"
course_counts = df.loc[allowed, "course name"].value_counts()

# 각 강의실 규모에 해당되는 과목 리스트 만들기
auditorium_list = list(course_counts[course_counts >= 80].index)
large_room_list = list(course_counts[(80 > course_counts) & (course_counts >= 40)].index)
medium_room_list = list(course_counts[(40 > course_counts) & (course_counts >= 15)].index)
small_room_list = list(course_counts[(15 > course_counts) & (course_counts > 4)].index)

# 강의실 이름 붙이기
for i in range(len(auditorium_list)):
    df.loc[(df["course name"] == sorted(auditorium_list)[i]) & allowed, "room assignment"] = "Auditorium-" + str(i + 1)

for i in range(len(large_room_list)):
    df.loc[(df["course name"] == sorted(large_room_list)[i]) & allowed, "room assignment"] = "Large-" + str(i + 1)
    
for i in range(len(medium_room_list)):
    df.loc[(df["course name"] == sorted(medium_room_list)[i]) & allowed, "room assignment"] = "Medium-" + str(i + 1)
    
for i in range(len(small_room_list)):
    df.loc[(df["course name"] == sorted(small_room_list)[i]) & allowed, "room assignment"] = "Small-" + str(i + 1)

# column 이름 바꾸기
df.rename(columns={"room assignment": "room number"}, inplace = True)
    
# 정답 출력
df
