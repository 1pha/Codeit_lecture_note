# %%
# 01. Mean

# %%
# 02. Quiz

# %%
# 03. Median

# %%
# 06. Pearson Correlation Coefficient
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('exam.csv')
df.corr()

sns.heatmap(df.corr(), annot=True)
